# %% [markdown]
# <a href="https://colab.research.google.com/github/elena1346/Practica-01/blob/main/ejercicios%20algoritmo%20sequencial.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Conocido el radio de la base y la altura de un cilindro, calcular su volumen
radio=float(input("ingrese el radio."))
altura=float(input("ingrese la altura."))
volumen=3.1416*((radio**2)*altura)
print(f"el volumen es {volumen}")
# Out:
# ingese el radio.1
# ingrese la altura.2
# el volumen es 6.2832

# %% [markdown]
# **Especificacion**
# *Interfaz*:
# entrada: radio, altura
# salida: volumen
# *Efecto:*
# condiciones de entrada: radio y altura son numeros reales
# Efecto producido: se calcula el volumen
# *Algoritmo:*
# volumen de un cilidro
# *Variables: *radio, altura
# *principio*:
# leer(radio)
# leer(altura)
# calcular volumen= 3.1416 * radio**2 * altura
# escribir(volumen)

# %% [markdown]
# **Especificacion**
# *Interfaz*:
# entrada: importe en euros, dollar_rate, pound_rate
# salida: importe equivalente en dolares, importe equivalente en dolares
# *Efecto:*
# condiciones de entrada: importe es una cantidad en euros, valores de cambio de monedas son numeros reales
# Efecto producido: se calcula la conversion
# *Algoritmo:*
# Conversion de euros a dolares y libras
# *Variables:*
# Ceur, dollarrate, poundrate
# *Principio*:
# leer(Ceur)
# leer(dollarrate)
# calcular Cdollar=Ceur * dollarrate
# escribir(Cpound)
# leer(poundrate)
# calcular Cpound=Ceur * poundrate
# escribir(Cpound)
# Fin
#
# ```
# # Tiene formato de código
# ```

# %%
#algoritmo conversor monedas
Ceur=float(input("Ingrese el importe en euros."))
dollarrate=float(input("Ingrese el valor de cambio de euro a dolar."))
Cdolar=Ceur*dollarrate
print(f"El importe equivalente en dolares es {Cdolar}.")
poundrate=float(input("Ingrese el cambio de euros a libras."))
Cpound=Ceur*poundrate
print(f"Y en libras, {Cpound}")
# Out:
# Ingrese el importe en euros.200
# Ingrese el valor de cambio de euro a dolar.1.15
# El importe equivalente en dolares es 229.99999999999997.
# Ingrese el cambio de euros a libras.0.89
# Y en libras, 178.0
